# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/My Drive/generated_sales_data.csv')
# Out:
# Mounted at /content/drive

# %%
df.head(10)
# Out:
#    SaleID ProductID   ProductName   Brand     Category  RetailerID  \
# 0       1         1        Laptop  BrandA  Electronics           1
# 1       2         2  Coffee Maker  BrandB   Appliances           1
# 2       3         5       Blender  BrandE   Appliances           1
# 3       4         1        Laptop  BrandA  Electronics           1
# 4       5         2  Coffee Maker  BrandB   Appliances           3
# 5       6         5       Blender  BrandE   Appliances           1
# 6       7         4    Desk Chair  BrandD    Furniture           1
# 7       8         3    Smartphone  BrandC  Electronics           1
# 8       9         4    Desk Chair  BrandD    Furniture           2
# 9      10         2  Coffee Maker  BrandB   Appliances           2
#
#      RetailerName  Channel       Location  Quantity Price        Date
# 0        TechGear   Online            NaN         3  4500  2024-02-05
# 1        TechGear   Online            NaN         1   100  2024-02-24
# ...

# %%
df.isnull().sum()
# Out:
# SaleID            0
# ProductID         0
# ProductName       0
# Brand             0
# Category          0
# RetailerID        0
# RetailerName      0
# Channel           0
# Location        323
# Quantity          0
# Price             0
# Date              0
# dtype: int64

# %%
df.map(lambda x: x == ' ').sum()
# Out:
# SaleID          0
# ProductID       1
# ProductName     0
# Brand           0
# Category        0
# RetailerID      0
# RetailerName    0
# Channel         0
# Location        0
# Quantity        0
# Price           0
# Date            0
# dtype: int64

# %%
df[df['ProductID'] == ' ']
# Out:
#     SaleID ProductID ProductName   Brand    Category  RetailerID  \
# 71    1001               Blender  BrandE  Appliances           2
#
#       RetailerName  Channel  Location  Quantity Price        Date
# 71  HomeEssentials  Offline  New York         4   800  2024-02-21

# %%
df.dtypes
# Out:
# SaleID           int64
# ProductID       object
# ProductName     object
# Brand           object
# Category        object
# RetailerID       int64
# RetailerName    object
# Channel         object
# Location        object
# Quantity         int64
# Price           object
# Date            object
# dtype: object

# %%
df[df['Price'].apply(lambda x: not x.isdigit())]
# Out:
#      SaleID ProductID ProductName   Brand     Category  RetailerID  \
# 289    1002         6   Desk Lamp  BrandF  Electronics           1
#
#     RetailerName Channel Location  Quantity   Price        Date
# 289     TechGear  Online      NaN         3  100USD  2024-03-01
